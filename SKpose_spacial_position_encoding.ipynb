# %% [markdown]
# # Read csv files into dataframe_dictionnary

# %%
import os
import pandas as pd
import gc

# Directory containing the CSV files
folder_path = 'D:\Thèse_Toufik\code\BVH\PyMO-master\InHARD_13\Skeleton\positions_3D'

# Initialize an empty dictionary to store DataFrames
df_dict = {}

# Iterate over files in the directory
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        print(filename)
        # Read CSV file into a DataFrame
        df = pd.read_csv(os.path.join(folder_path, filename))
        
        # Add DataFrame to the dictionary with the filename (without extension) as key
        df_dict[os.path.splitext(filename)[0]] = df

# Now dataframes_dict contains all your DataFrames, with filenames as keys
# Out:
# P10_R01.csv
# P10_R02.csv
# P10_R03.csv
# P11_R01.csv
# P11_R02.csv
# P12_R01.csv
# P12_R02.csv
# P13_R02.csv
# P14_R01.csv
# P14_R02.csv
# P15_R01.csv
# P15_R02.csv
# P16_R01.csv
# P16_R02.csv

# %%
df_dict[list(df_dict.keys())[1]]
# Out:
#        Hips_Xposition  Hips_Yposition  Hips_Zposition  Spine_Xposition  \
# 0           36.880108      101.803375        3.465991        43.136909
# 1           36.893082      101.797951        3.443803        43.079189
# 2           36.916389      101.788857        3.423668        43.049055
# 3           36.952560      101.773193        3.416687        43.037153
# 4           36.986435      101.769005        3.418525        43.024006
# ...               ...             ...             ...              ...
# 44882       86.066505      102.059998      105.225143        93.202752
# 44883       85.906425      102.070465      105.656837        93.068268
# 44884       85.783409      102.080658      105.954781        92.987645
# 44885       85.679153      102.093544      106.167625        92.930853
# 44886       85.545395      102.100800      106.335022        92.854026
#
#        Spine_Yposition  Spine_Zposition  Spine1_Xposition  Spine1_Yposition  \
# 0           132.434437         3.704771         45.121288        153.571216
# 1           132.443900         3.608924         45.040700        153.583049
# 2           132.445950         3.514720         44.993137        153.586754
# 3           132.440165         3.431041         44.965747        153.582732
# 4           132.445258         3.354347         44.936803        153.589713
# ...                ...              ...               ...               ...
# 44882       132.491988       105.634253         94.885395        153.637821
# 44883       132.495440       106.105714         94.794742        153.639485
# 44884       132.494143       106.447861         94.771032        153.633288
# 44885       132.494232       106.701162         94.775662        153.627888
# 44886       132.486140       106.907768         94.758956        153.613692
#
#        Spine1_Zposition  Spine2_Xposition  ...  RightUpLeg_Zposition  \
# 0              3.135742         46.555790  ...            -17.189074
# 1              3.030092         46.460491  ...            -17.204382
# 2              2.927299         46.402150  ...            -17.213940
# 3              2.834404         46.365338  ...            -17.210159
# 4              2.747250         46.326372  ...            -17.195559
# ...                 ...               ...  ...                   ...
# 44882        104.781001         95.859493  ...             84.940291
# 44883        105.300397         95.824611  ...             85.605644
# 44884        105.705041         95.870993  ...             85.918876
# 44885        106.023861         95.949480  ...             86.148189
# 44886        106.295210         96.003152  ...             86.331713
#
#        RightLeg_Xposition  RightLeg_Yposition  RightLeg_Zposition  \
# 0               41.300860            7.374437          -23.588728
# 1               41.311757            7.347655          -23.655507
# 2               41.316792            7.318494          -23.726179
# 3               41.299285            7.281860          -23.784293
# 4               41.266077            7.255740          -23.835934
# ...                   ...                 ...                 ...
# 44882           89.904946            7.202610           76.009462
# 44883           90.072503            7.302559           75.757538
# 44884           90.059891            7.355964           75.808028
# 44885           90.069898            7.405309           75.782830
# 44886           90.094665            7.445411           75.715479
#
#        RightFoot_Xposition  RightFoot_Yposition  RightFoot_Zposition  \
# 0                46.211816           -82.728082           -27.618755
# 1                46.212808           -82.737937           -27.618048
# 2                46.188688           -82.749049           -27.622589
# 3                46.158309           -82.760894           -27.644778
# 4                46.099661           -82.773663           -27.657582
# ...                    ...                  ...                  ...
# 44882            87.680766           -82.927426            71.832737
# 44883            88.087987           -82.862152            71.096256
# 44884            88.275056           -82.830590            70.783676
# 44885            88.460524           -82.801088            70.460003
# 44886            88.636927           -82.770444            70.156582
#
#        RightFoot_Nub_Xposition  RightFoot_Nub_Yposition  \
# 0                    39.444121               -90.353083
# 1                    39.450637               -90.368815
# 2                    39.431948               -90.385270
# 3                    39.400177               -90.405301
# 4                    39.353191               -90.425359
# ...                        ...                      ...
# 44882                75.015316               -90.827303
# 44883                75.418481               -90.777690
# 44884                75.597899               -90.760175
# 44885                75.859077               -90.740605
# 44886                76.032606               -90.724126
#
#        RightFoot_Nub_Zposition
# 0                   -44.924805
# 1                   -44.923667
# 2                   -44.927973
# 3                   -44.946004
# 4                   -44.960137
# ...                        ...
# 44882                58.393241
# 44883                57.669805
# 44884                57.372744
# 44885                56.983752
# 44886                56.691378
#
# [44887 rows x 216 columns]

# %% [markdown]
# # resample to 30 fps

# %%
import pandas as pd

df_dict_30fps = {}
step = 4 # for 30fps: default 119fps 


# Define a function to create the new dataframe
def create_new_dataframe(old_df, interval):
    new_data = []
    for i in range(0, len(old_df), interval):
        # Take the last row in each interval
        new_data.append(old_df.iloc[i:i+interval].iloc[-1])
    # Create a new dataframe from the collected data
    new_dataframe = pd.DataFrame(new_data)
    return new_dataframe

# Iterate through the original dictionary and create new filtered DataFrames
for key, df in df_dict.items():
    print(key)
    # Create the new dataframe
    df_dict_30fps[key] = create_new_dataframe(df, step)
# Out:
# P10_R01
# P10_R02
# P10_R03
# P11_R01
# P11_R02
# P12_R01
# P12_R02
# P13_R02
# P14_R01
# P14_R02
# P15_R01
# P15_R02
# P16_R01
# P16_R02

# %%
df_dict_30fps[list(df_dict_30fps.keys())[1]]
# Out:
#        Hips_Xposition  Hips_Yposition  Hips_Zposition  Spine_Xposition  \
# 3           36.952560      101.773193        3.416687        43.037153
# 7           37.045059      101.754929        3.437020        42.960324
# 11          37.231209      101.696060        3.519362        43.046241
# 15          37.593231      102.010742        3.251856        43.296059
# 19          37.718998      102.232826        3.199169        43.395517
# ...               ...             ...             ...              ...
# 44871       88.010147      103.192833      103.090599        94.658662
# 44875       87.144905      102.097847      104.091057        94.116522
# 44879       86.558273      101.983437      104.428268        93.731859
# 44883       85.906425      102.070465      105.656837        93.068268
# 44886       85.545395      102.100800      106.335022        92.854026
#
#        Spine_Yposition  Spine_Zposition  Spine1_Xposition  Spine1_Yposition  \
# 3           132.440165         3.431041         44.965747        153.582732
# 7           132.453425         3.124181         44.830212        153.600221
# 11          132.410138         2.976449         44.881888        153.551232
# 15          132.741520         2.485206         45.097139        153.882067
# 19          132.967024         2.305919         45.037899        154.123917
# ...                ...              ...               ...               ...
# 44871       133.742727       103.262170         96.107438        154.871616
# 44875       132.569547       104.409634         95.759829        153.688665
# 44879       132.408709       104.811884         95.369682        153.545795
# 44883       132.495440       106.105714         94.794742        153.639485
# 44886       132.486140       106.907768         94.758956        153.613692
#
#        Spine1_Zposition  Spine2_Xposition  ...  RightUpLeg_Zposition  \
# 3              2.834404         46.365338  ...            -17.210159
# 7              2.486053         46.190487  ...            -17.151514
# 11             2.293589         46.211680  ...            -17.027443
# 15             1.760900         46.405536  ...            -17.206889
# 19             1.576107         46.154172  ...            -17.207176
# ...                 ...               ...  ...                   ...
# 44871        101.891705         96.847656  ...             82.882620
# 44875        103.232018         96.684493  ...             83.986063
# 44879        103.787980         96.257737  ...             84.340973
# 44883        105.300397         95.824611  ...             85.605644
# 44886        106.295210         96.003152  ...             86.331713
#
#        RightLeg_Xposition  RightLeg_Yposition  RightLeg_Zposition  \
# 3               41.299285            7.281860          -23.784293
# 7               40.956871            7.157416          -23.870756
# 11              40.726958            7.021675          -23.841848
# 15              40.575796            7.275590          -24.269471
# 19              40.490123            7.495938          -24.558355
# ...                   ...                 ...                 ...
# 44871           90.125627            8.178924           75.763849
# 44875           90.061796            7.161955           75.968310
# 44879           90.173858            7.105967           75.383017
# 44883           90.072503            7.302559           75.757538
# 44886           90.094665            7.445411           75.715479
#
#        RightFoot_Xposition  RightFoot_Yposition  RightFoot_Zposition  \
# 3                46.158309           -82.760894           -27.644778
# 7                45.880332           -82.817783           -27.690887
# 11               45.692374           -82.845177           -27.732785
# 15               45.394477           -82.869953           -27.870423
# 19               45.456293           -82.848892           -28.217447
# ...                    ...                  ...                  ...
# 44871            85.444605           -82.928591            74.136261
# 44875            86.575490           -82.921267            72.931727
# 44879            87.383597           -82.911959            71.994735
# 44883            88.087987           -82.862152            71.096256
# 44886            88.636927           -82.770444            70.156582
#
#        RightFoot_Nub_Xposition  RightFoot_Nub_Yposition  \
# 3                    39.400177               -90.405301
# 7                    39.188594               -90.483520
# 11                   39.053537               -90.520718
# 15                   38.851977               -90.567458
# 19                   38.972338               -90.563533
# ...                        ...                      ...
# 44871                72.719265               -90.674768
# 44875                73.830065               -90.753408
# 44879                74.642089               -90.782801
# 44883                75.418481               -90.777690
# 44886                76.032606               -90.724126
#
#        RightFoot_Nub_Zposition
# 3                   -44.946004
# 7                   -45.008474
# 11                  -45.066384
# 15                  -45.230891
# 19                  -45.592267
# ...                        ...
# 44871                60.663911
# 44875                59.528241
# 44879                58.610208
# 44883                57.669805
# 44886                56.691378
#
# [11222 rows x 216 columns]

# %%
# Reset the row index to default integer-based index
for datagram_key, dataframe in df_dict_30fps.items():
    df_dict_30fps[datagram_key] = dataframe.reset_index(drop=True)

# %% [markdown]
# # Position encoding

# %% [markdown]
# ### Generate position encoding

# %%
import math
import numpy as np

def pn(x, N):
    """
    Generate positional encoding for a single coordinate (x, y, or z).

    Args:
    - x (float): The coordinate to be encoded (x, y, or z).
    - N (int): The dimension of the embedding, must be divisible by 2.

    Returns:
    - pos_encoding (np.ndarray): The positional encoding for the coordinate.
    """
    result = []
    for i in range(N + 1):
        result.append(np.float32(math.sin(2**i * math.pi * x)))
        result.append(np.float32(math.cos(2**i * math.pi * x)))
    return result

# %%
df = df_dict_30fps[list(df_dict_30fps.keys())[0]]

# Extract unique joint names from column names while preserving order
joints = []
for col in df.columns:
    joint = '_'.join(col.split('_')[:-1])
    if joint not in joints:
        joints.append(joint)
print(joints)
# Out:
# ['Hips', 'Spine', 'Spine1', 'Spine2', 'Spine3', 'LeftShoulder', 'LeftArm', 'LeftForeArm', 'LeftHand', 'LeftInHandPinky', 'LeftHandPinky1', 'LeftHandPinky2', 'LeftHandPinky3', 'LeftHandPinky3_Nub', 'LeftInHandRing', 'LeftHandRing1', 'LeftHandRing2', 'LeftHandRing3', 'LeftHandRing3_Nub', 'LeftInHandMiddle', 'LeftHandMiddle1', 'LeftHandMiddle2', 'LeftHandMiddle3', 'LeftHandMiddle3_Nub', 'LeftInHandIndex', 'LeftHandIndex1', 'LeftHandIndex2', 'LeftHandIndex3', 'LeftHandIndex3_Nub', 'LeftHandThumb1', 'LeftHandThumb2', 'LeftHandThumb3', 'LeftHandThumb3_Nub', 'RightShoulder', 'RightArm', 'RightForeArm', 'RightHand', 'RightInHandPinky', 'RightHandPinky1', 'RightHandPinky2', 'RightHandPinky3', 'RightHandPinky3_Nub', 'RightInHandRing', 'RightHandRing1', 'RightHandRing2', 'RightHandRing3', 'RightHandRing3_Nub', 'RightInHandMiddle', 'RightHandMiddle1', 'RightHandMiddle2', 'RightHandMiddle3', 'RightHandMiddle3_Nub', 'RightInHandIndex', 'RightHandIndex1', 'RightHandIndex2', 'RightHandIndex3', 'RightHandIndex3_Nub', 'RightHandThumb1', 'RightHandThumb2', 'RightHandThumb3', 'RightHandThumb3_Nub', 'Neck', 'Head', 'Head_Nub', 'LeftUpLeg', 'LeftLeg', 'LeftFoot', 'LeftFoot_Nub', 'RightUpLeg', 'RightLeg', 'RightFoot', 'RightFoot_Nub']

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# Define a list of d_model values to test
#d_models = [1, 2, 3, 4]
N= 1

# Initialize an empty dictionary to store the encoded DataFrames
encoded_data_dict = {}

# Apply the encoding process for each DataFrame in the original dictionary
for key, df in df_dict_30fps.items():
    print(key)
    encoded_df = pd.DataFrame()
    for joint in joints:
        for coord_suffix in ['X', 'Y', 'Z']:
            coord_col = f'{joint}_{coord_suffix}position'
            encoded_col = f'{joint}_{coord_suffix}position_enc_d{N}'
            encoded_df[encoded_col] = df.apply(lambda row: pn(row[coord_col], N), axis=1)
    encoded_data_dict[key] = encoded_df
print('Done !')
# Out:
# P10_R01
# P10_R02
# P10_R03
# P11_R01
# P11_R02
# P12_R01
# P12_R02
# P13_R02
# P14_R01
# P14_R02
# P15_R01
# P15_R02
# P16_R01
# P16_R02
# Done !

# %%
encoded_data_dict[list(encoded_data_dict.keys())[1]]

# %%
import pandas as pd
import numpy as np

# Assuming df is your DataFrame with 216 columns
# Create a sample DataFrame
num_joints = 72
num_dimensions = 3  # x, y, z
num_columns = num_joints * num_dimensions
d_pe= 4

# Define the function to concatenate tuples into vectors for each DataFrame
vectors = []
def concat_tuples_to_vector(df):
    for _, row in df.iterrows():
        vector = list(np.concatenate(row.values))
        vectors.append(vector)
    return pd.DataFrame(vectors, columns=[f'vec_{i}' for i in range(df.shape[1]*d_pe)])

    
# Apply the function to each DataFrame in the dictionary and update the dictionary in place
for key in encoded_data_dict.keys():
    print(key)
    encoded_data_dict[key] = concat_tuples_to_vector(encoded_data_dict[key])

print('DONE !')

# %%
encoded_data_dict[list(encoded_data_dict.keys())[1]]

# %% [markdown]
# # Save to npy

# %%
import numpy as np

# Create a directory to store the npy files (optional)
output_directory = 'D:\Thèse_Toufik\Datasets\\npy_30fps_pose_N_spacial'  #

# Create the directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

print('30 fps InHARD-13 position features with N_x spacial: ') # x: the value of N
for key, df in encoded_data_dict.items():
    print(key)

    # Save the normalized DataFrame as a .npy file
    output_filepath = os.path.join(output_directory, f"{key}.npy")
    np.save(output_filepath, df.to_numpy())
    
    d=np.load(output_filepath)
    print(d.shape)
# Out:
# 30 fps InHARD-13 position features with N1 spacial:
# P01_R01
# (15627, 864)
# P01_R02
# (28740, 864)
# P01_R03
# (41301, 864)
# P02_R01
# (53924, 864)
# P02_R02
# (64328, 864)
# P03_R01
# (83150, 864)
# P03_R03
# (94907, 864)
# P03_R04
# (107304, 864)
# P04_R01
# (126028, 864)
# P04_R02
# (139759, 864)
# P05_R01
# (163952, 864)
# P05_R02
# (180850, 864)
# P05_R03
# (196020, 864)
# P05_R04
# (208328, 864)
# P06_R01
# (234670, 864)
# P07_R01
# (245049, 864)
# P07_R02
# (254830, 864)
# P08_R01
# (267912, 864)
# P08_R02
# (278679, 864)
# P08_R03
# (287444, 864)
# P08_R04
# (295866, 864)
# P09_R01
# (304229, 864)
# P09_R02
# (311590, 864)
# P09_R03
# (318967, 864)
